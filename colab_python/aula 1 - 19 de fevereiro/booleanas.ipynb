# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurGpolo/Python/blob/main/booleanas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula01 -> PYTHON BOOLEANAS

# %%
verdade = True

print("É verdade?", str(verdade))
# Out:
# É verdade? True

# %%
nome = "Arthur"

sobrenome = "Gonçalves Polo"

print("Nome:", nome,sobrenome)
# Out:
# Nome: Arthur Gonçalves Polo
