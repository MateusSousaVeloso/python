# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurGpolo/Python/blob/main/hellow_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula01 -> PYTHON

# %%
print("Hellow World!")
# Out:
# Hellow World!

# %%
a = 2
b = 3

soma = a + b

print(a, "+", b, "=", soma)
# Out:
# 2 + 3 = 5

# %% [markdown]
# str() -> serve para tornar alguma variável em string

# %%
numero_inteiro = 10

numero_decimal = 0.75

conta = numero_inteiro * numero_decimal

print(numero_inteiro, "x", numero_decimal, "=", conta)

print(type(conta))
# Out:
# 10 x 0.75 = 7.5
# <class 'float'>

# %% [markdown]
# print(type(variável)) -> mostra o tipo da variável
