# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurGpolo/Python/blob/main/inputs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula01 -> PYTHON INPUTS

# %%
nome = input("Digite deu nome: ")

print("\nSeja bem vindo", nome)
# Out:
# Digite deu nome: Arthur
#
# Seja bem vindo Arthur

# %%
numero_fornecido = int(input("Digite um numero: "))

print("\nO numero fornecido foi:", numero_fornecido)
print("\nSoma =", numero_fornecido + 10)
# Out:
# Digite um numero: 10
#
# O numero fornecido foi: 10
#
# Soma = 20

# %% [markdown]
# int(), float() e boolean() -> Servem para definir o tipo do input

# %%
nome = input("Qual o seu nome: ")
cor = input("Qual a sua cor favorita: ")

print("\nNossa,",nome, "minha cor favorita também é", cor)
# Out:
# Qual o seu nome: Arthur
# Qual a sua cor favorita: preto
#
# Nossa, Arthur minha cor favorita também é preto

# %%
nome = input("Informe seu nome: ")
sobrenome = input("Informe seu sobrenome: ")

print("\nSeu nome completo é:",nome,sobrenome)
# Out:
# Informe seu nome: Arthur
# Informe seu sobrenome: Gonçalves Polo
#
# Seu nome completo é: Arthur Gonçalves Polo
