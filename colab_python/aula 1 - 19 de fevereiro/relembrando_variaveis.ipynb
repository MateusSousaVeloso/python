# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurGpolo/Python/blob/main/relembrando_variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 02 -> PYTHON RELEMBRANDO VARIÁVEIS

# %%
a = 10
a + a

nome = 'Arthur'
sobrenome = 'Polo'

nome + ' ' + sobrenome
# Out:
# 'Arthur Polo'

# %% [markdown]
# *   No Python não é extritamente necessário Print() para realizar operações.
# *   Sem Print() ele só realiza a última operação do código.

# %%
a = 10
b = 3

potencia = a ** b

print(a, 'elevado a', b, '=', potencia)
# Out:
# 10 elevado a 3 = 1000

# %% [markdown]
# A operação ** serve para elevar uma variável.
