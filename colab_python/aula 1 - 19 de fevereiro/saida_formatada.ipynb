# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurGpolo/Python/blob/main/saida_formatada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula01 -> PYTHON SAIDAS FORMATADAS

# %%
a = 54
b = 12

print("a = %d" %a)
print("%d + %d = %d" %(a, b, a + b))
# Out:
# a = 54
# 54 + 12 = 66

# %%
palavra = "prêmio"
valor = 1000

print("%s = R$%.2f" %(palavra, valor))
# Out:
# prêmio = R$1000.00

# %% [markdown]
# %.2f -> Serve para definir a quantidade de casas decimais de uma variável float
